# %% [markdown]
# # Welcome to MICE tutorial

# %% [markdown]
# Why Multiple Imputation Chained Equation?
#
# Scenario - Data for “predicting employee happiness 😁 index” has some missing employment status (0-100% FTE) and salary attributes along with job title, location, team and function. You need to impute those missing values.
# Standard impute strategies would simply take the mean or median producing insignificant results.
# MICE performs a special imputation that uses as much information as possible from the other features (independent variables) to impute depending on each employee feature.

# %% [markdown]
# Link to the [MICE Github](https://github.com/statsmodels/statsmodels/blob/master/statsmodels/imputation/mice.py)

# %% [markdown]
# ## Prepare the notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sys
import seaborn as sns
import warnings
warnings.simplefilter('ignore')

from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.preprocessing import Imputer, LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.utils import check_array
from time import time

from statsmodels.imputation.mice import MICEData
from statsmodels.imputation.mice import MICE as mice
from statsmodels.regression.linear_model import OLS
from MICE import MiceImputer
# %matplotlib inline

# %% [markdown]
# ## Load the data

# %%
train = pd.read_csv("smalldata.csv")
train['index'] = train['Unnamed: 0']
train = train.drop('Unnamed: 0', axis = 1)
train.head()
# Out:
#                                           Function          Use  \
# 0                                         NO_LABEL     NO_LABEL
# 1                                         NO_LABEL     NO_LABEL
# 2  Special Population Program Management & Support         ISPD
# 3                             Teacher Compensation  Instruction
# 4                         Extended Time & Tutoring  Instruction
#
#                    Sharing   Reporting       Student_Type Position_Type  \
# 0                 NO_LABEL  Non-School           NO_LABEL      NO_LABEL
# 1                 NO_LABEL    NO_LABEL           NO_LABEL      NO_LABEL
# 2  Leadership & Management  Non-School  Special Education         Other
# 3          School Reported      School                ELL       Teacher
# 4          School Reported      School        Unspecified       Teacher
#
#                   Object_Type     Pre_K   Operating_Status  \
# 0          Supplies/Materials  NO_LABEL  PreK-12 Operating
# 1                    NO_LABEL  NO_LABEL      Non-Operating
# 2  Other Compensation/Stipend  NO_LABEL  PreK-12 Operating
# 3    Base Salary/Compensation  NO_LABEL  PreK-12 Operating
# 4  Other Compensation/Stipend  Non PreK  PreK-12 Operating
#
#                                   Object_Description   ...    \
# 0                                           SUPPLIES   ...
# 1                                  EMPLOYEE BENEFITS   ...
# 2                     WORKSHOP PARTICIPANT             ...
# 3                                                NaN   ...
# 4  Salaries And Wages For Teachers And Other Prof...   ...
#
#              Location_Description  FTE            Function_Description  \
# 0                             NaN  NaN                     INSTRUCTION
# 1            PERSONNEL-PAID LEAVE  NaN                     NON-PROJECT
# 2  ESE                             NaN  INST STAFF TRAINING SVCS
# 3                             NaN  1.0                             NaN
# 4                         School   NaN            Social Work Services
#
#        Facility_or_Department    Position_Extra        Total  \
# 0                         NaN               NaN    534.00000
# 1                         NaN     ADMINISTRATOR          NaN
# 2                         NaN               NaN    382.72000
# 3                         NaN               NaN  64644.64165
# 4  Instruction And Curriculum  TEACHER BACHELOR     78.71418
#
#                           Program_Description  \
# 0  HIGH SCHOOL GENERAL EDUCATION PROGRAM 9-12
# 1                              STAFF SERVICES
# 2                                         NaN
# 3                                         NaN
# 4                               Undistributed
#
#                                  Fund_Description  \
# 0                                    General Fund
# 1                                             NaN
# 2                  FED THRU STATE-CASH ADVANCE
# 3                                             NaN
# 4  Title Iv Part B  Century Community Learning Ce
#
#                            Text_1   index
# 0                             NaN  414351
# 1                         CENTRAL  156609
# 2  IDEA  PART B                     75964
# 3                             NaN  172213
# 4                   EXTENDED DAYS  348071
#
# [5 rows x 26 columns]

# %% [markdown]
# bascially get all the stuff from our main notebook here and run using miceData

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# * In this step, We are removing the white strips and capitalizing our categorical variables

# %%
train_trimmed = train.apply(lambda x: x.str.strip() if x.dtype == "object" else x) #change to category if ran 
#the cell which changes object to category
train_trimmed = train_trimmed.apply(lambda x: x.str.upper() if x.dtype == "object" else x)
train_trimmed.head()
# Out:
#                                           Function          Use  \
# 0                                         NO_LABEL     NO_LABEL
# 1                                         NO_LABEL     NO_LABEL
# 2  SPECIAL POPULATION PROGRAM MANAGEMENT & SUPPORT         ISPD
# 3                             TEACHER COMPENSATION  INSTRUCTION
# 4                         EXTENDED TIME & TUTORING  INSTRUCTION
#
#                    Sharing   Reporting       Student_Type Position_Type  \
# 0                 NO_LABEL  NON-SCHOOL           NO_LABEL      NO_LABEL
# 1                 NO_LABEL    NO_LABEL           NO_LABEL      NO_LABEL
# 2  LEADERSHIP & MANAGEMENT  NON-SCHOOL  SPECIAL EDUCATION         OTHER
# 3          SCHOOL REPORTED      SCHOOL                ELL       TEACHER
# 4          SCHOOL REPORTED      SCHOOL        UNSPECIFIED       TEACHER
#
#                   Object_Type     Pre_K   Operating_Status  \
# 0          SUPPLIES/MATERIALS  NO_LABEL  PREK-12 OPERATING
# 1                    NO_LABEL  NO_LABEL      NON-OPERATING
# 2  OTHER COMPENSATION/STIPEND  NO_LABEL  PREK-12 OPERATING
# 3    BASE SALARY/COMPENSATION  NO_LABEL  PREK-12 OPERATING
# 4  OTHER COMPENSATION/STIPEND  NON PREK  PREK-12 OPERATING
#
#                                   Object_Description   ...    \
# 0                                           SUPPLIES   ...
# 1                                  EMPLOYEE BENEFITS   ...
# 2                               WORKSHOP PARTICIPANT   ...
# 3                                                NaN   ...
# 4  SALARIES AND WAGES FOR TEACHERS AND OTHER PROF...   ...
#
#    Location_Description  FTE      Function_Description  \
# 0                   NaN  NaN               INSTRUCTION
# 1  PERSONNEL-PAID LEAVE  NaN               NON-PROJECT
# 2                   ESE  NaN  INST STAFF TRAINING SVCS
# 3                   NaN  1.0                       NaN
# 4                SCHOOL  NaN      SOCIAL WORK SERVICES
#
#        Facility_or_Department    Position_Extra        Total  \
# 0                         NaN               NaN    534.00000
# 1                         NaN     ADMINISTRATOR          NaN
# 2                         NaN               NaN    382.72000
# 3                         NaN               NaN  64644.64165
# 4  INSTRUCTION AND CURRICULUM  TEACHER BACHELOR     78.71418
#
#                           Program_Description  \
# 0  HIGH SCHOOL GENERAL EDUCATION PROGRAM 9-12
# 1                              STAFF SERVICES
# 2                                         NaN
# 3                                         NaN
# 4                               UNDISTRIBUTED
#
#                                  Fund_Description         Text_1   index
# 0                                    GENERAL FUND            NaN  414351
# 1                                             NaN        CENTRAL  156609
# 2                     FED THRU STATE-CASH ADVANCE   IDEA  PART B   75964
# 3                                             NaN            NaN  172213
# 4  TITLE IV PART B  CENTURY COMMUNITY LEARNING CE  EXTENDED DAYS  348071
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Imputation using statsmodel

# %% [markdown]
# MICE stands for Multiple Imputation with Chained Equations. We know that FTE and Total Budget are document specific, i.e. a full-time employee and a higher paid employee would not have the same role, designation, operation status, etc as a part-time employee hired on a contract basis. We cannot impute them by taking a mean or median of the entire dataset. Hence, we need a special imputation method that can use as much information as possible from the other features (independent variables) to impute depending on each document (employee) feature.

# %%
# Drop our target features
train_imp = train_trimmed.drop(['Function', 'Use', 'Sharing', 'Reporting', 'Student_Type',
       'Position_Type', 'Object_Type', 'Pre_K', 'Operating_Status'],axis=1)
train_imp.head()
# Out:
#                                   Object_Description  \
# 0                                           SUPPLIES
# 1                                  EMPLOYEE BENEFITS
# 2                               WORKSHOP PARTICIPANT
# 3                                                NaN
# 4  SALARIES AND WAGES FOR TEACHERS AND OTHER PROF...
#
#                         Text_2                  SubFund_Description  \
# 0                          NaN  HIGH SCHOOL GENERAL ED PROGRAM 9-12
# 1  UNASSIGNED PERS/PAID LEAVES                         GENERAL FUND
# 2                          NaN                                  NaN
# 3      ESL/BILINGUAL EDUCATION                                LOCAL
# 4                          NaN             CASE PARTNERSHIP PROJECT
#
#           Job_Title_Description Text_3         Text_4 Sub_Object_Description  \
# 0                           NaN    NaN            NaN                    NaN
# 1                     PRINCIPAL    NaN            NaN                    NaN
# 2         ESE SCHOOL SPECIALIST    NaN            NaN                    NaN
# 3                       TEACHER    NaN            NaN                    NaN
# 4  TEACHER, BILINGUAL EDUCATION    NaN  UNDISTRIBUTED           EXTENDED DAY
#
#    Location_Description  FTE      Function_Description  \
# 0                   NaN  NaN               INSTRUCTION
# 1  PERSONNEL-PAID LEAVE  NaN               NON-PROJECT
# 2                   ESE  NaN  INST STAFF TRAINING SVCS
# 3                   NaN  1.0                       NaN
# 4                SCHOOL  NaN      SOCIAL WORK SERVICES
#
#        Facility_or_Department    Position_Extra        Total  \
# 0                         NaN               NaN    534.00000
# 1                         NaN     ADMINISTRATOR          NaN
# 2                         NaN               NaN    382.72000
# 3                         NaN               NaN  64644.64165
# 4  INSTRUCTION AND CURRICULUM  TEACHER BACHELOR     78.71418
#
#                           Program_Description  \
# 0  HIGH SCHOOL GENERAL EDUCATION PROGRAM 9-12
# 1                              STAFF SERVICES
# 2                                         NaN
# 3                                         NaN
# 4                               UNDISTRIBUTED
#
#                                  Fund_Description         Text_1   index
# 0                                    GENERAL FUND            NaN  414351
# 1                                             NaN        CENTRAL  156609
# 2                     FED THRU STATE-CASH ADVANCE   IDEA  PART B   75964
# 3                                             NaN            NaN  172213
# 4  TITLE IV PART B  CENTURY COMMUNITY LEARNING CE  EXTENDED DAYS  348071

# %%
train_imp.isnull().sum()
# Out:
# Object_Description         2
# Text_2                    19
# SubFund_Description        6
# Job_Title_Description      5
# Text_3                    19
# Text_4                    17
# Sub_Object_Description    17
# Location_Description      15
# FTE                       15
# Function_Description       4
# Facility_or_Department    18
# Position_Extra             7
# Total                      1
# Program_Description        4
# Fund_Description          10
# Text_1                     7
# index                      0
# dtype: int64

# %%
import re
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
for column_name in train_imp.columns:
    #  Removing characters other than alphabets
    if train_imp[column_name].dtype == object:
        temp = train_imp[column_name].astype(str).map(lambda x: re.sub(r'\W+', '', x))        
        train_imp[column_name] = le.fit_transform(temp)
    else:
        pass

# %% [markdown]
# #### Using default mean/median

# %%
train_wo_mice = train_imp.fillna(train_imp.mean())
train_wo_mice
# Out:
#     Object_Description  Text_2  SubFund_Description  Job_Title_Description  \
# 0                   12       3                    2                     15
# 1                    2       2                    1                      3
# 2                   14       3                    7                      1
# 3                   15       0                    4                      4
# 4                    9       3                    0                      5
# 5                    1       3                    1                      9
# 6                   11       3                    1                      9
# 7                    4       3                    6                     15
# 8                    1       3                    1                      2
# 9                    6       3                    7                      0
# 10                   2       3                    1                      9
# 11                  10       1                    1                      8
# 12                   5       3                    3                     15
# 13                  15       3                    7                      7
# 14                   1       3                    1                     14
# 15                   1       3                    1                      6
# 16                  13       1                    1                     10
# 17                   8       3                    5                     13
# 18                   3       3                    7                     15
# 19                   0       3                    7                     11
# 20                   8       3                    5                     13
# 21                   9       3                    5                     12
# 22                   7       3                    7                     15
#
#     Text_3  Text_4  Sub_Object_Description  Location_Description       FTE  \
# 0        3       5                       5                     4  0.730088
# 1        3       5                       5                     1  0.730088
# 2        3       5                       5                     0  0.730088
# 3        3       5                       5                     4  1.000000
# 4        3       4                       0                     2  0.730088
# 5        3       5                       5                     4  0.730088
# 6        0       5                       5                     4  1.004141
# 7        3       5                       2                     4  0.730088
# 8        3       5                       5                     4  0.730088
# 9        3       3                       5                     4  0.952253
# 10       1       5                       5                     4  0.730088
# 11       2       5                       5                     4  0.004310
# 12       3       5                       5                     4  0.730088
# 13       3       5                       5                     4  1.000000
# 14       3       5                       5                     4  0.730088
# 15       3       5                       5                     4  0.730088
# 16       1       5                       5                     4  0.730088
# 17       3       1                       3                     2  0.730088
# 18       3       0                       1                     3  0.730088
# 19       3       5                       5                     2  1.000000
# 20       3       1                       3                     2  0.730088
# 21       3       5                       4                     2  0.880000
# 22       3       2                       5                     4  0.000000
#
#     Function_Description  Facility_or_Department  Position_Extra  \
# 0                      2                       3               8
# 1                      4                       3               0
# 2                      3                       3               8
# 3                      7                       3               8
# 4                      6                       2               5
# 5                      4                       3               7
# 6                      4                       3               4
# 7                      5                       3               8
# 8                      4                       3               7
# 9                      7                       3               2
# 10                     4                       3               4
# 11                     4                       3               4
# 12                     2                       3               8
# 13                     7                       3               3
# 14                     4                       3               7
# 15                     4                       3               7
# 16                     4                       3               4
# 17                     2                       0               5
# 18                     1                       1               8
# 19                     0                       3               8
# 20                     2                       0               1
# 21                     2                       0               5
# 22                     7                       3               6
#
#            Total  Program_Description  Fund_Description  Text_1   index
# 0     534.000000                    5                 1       8  414351
# 1   14280.675006                   10                 8       0  156609
# 2     382.720000                   13                 0       4   75964
# 3   64644.641650                   13                 8       8  172213
# 4      78.714180                   12                 7       2  348071
# 5     -63.110000                    2                 8       1  446304
# 6   52414.464330                    3                 8       5   66302
# 7   -1062.560000                   13                 6       7  325427
# 8     -15.020000                    2                 8       1   49981
# 9   26639.987380                    6                 3       8   29225
# 10    698.860000                    3                 8       5  355235
# 11    129.544985                    4                 8       5  281376
# 12    327.160000                    7                 4       8  111770
# 13  47732.070000                    9                 1       8  214157
# 14    -28.250000                    2                 8       1  341782
# 15   -463.010000                    2                 8       1   29389
# 16     19.175120                    3                 8       5  269605
# 17    152.631020                    1                 2       6  381109
# 18   3693.590000                    0                 2       8  370555
# 19  49676.601090                   13                 1       8  295692
# 20   1945.237692                    1                 2       6  440127
# 21  66465.182680                    8                 2       6  444226
# 22    272.220000                   11                 5       3  151100

# %% [markdown]
# #### Using set_imputer

# %%
imp = MICEData(train_imp)
imp.set_imputer('FTE', formula='Object_Description'+'Function_Description'+'Total')
imp.data.FTE
# Out:
# 0     0.149912
# 1     0.149912
# 2     0.149912
# 3     1.000000
# 4     0.149912
# 5     0.149912
# 6     1.004141
# 7     0.149912
# 8     0.149912
# 9     0.952253
# 10    0.149912
# 11    0.004310
# 12    0.149912
# 13    1.000000
# 14    0.149912
# 15    0.149912
# 16    0.149912
# 17    0.149912
# 18    0.149912
# 19    1.000000
# 20    0.149912
# 21    0.880000
# 22    0.000000
# Name: FTE, dtype: float64

# %% [markdown]
# #### Using default method

# %%
imp2 = MICEData(train_imp)
imp2.data.to_csv
# Out:
# <bound method DataFrame.to_csv of     Object_Description  Text_2  SubFund_Description  Job_Title_Description  \
# 0                   12       3                    2                     15
# 1                    2       2                    1                      3
# 2                   14       3                    7                      1
# 3                   15       0                    4                      4
# 4                    9       3                    0                      5
# 5                    1       3                    1                      9
# 6                   11       3                    1                      9
# 7                    4       3                    6                     15
# 8                    1       3                    1                      2
# 9                    6       3                    7                      0
# 10                   2       3                    1                      9
# 11                  10       1                    1                      8
# 12                   5       3                    3                     15
# 13                  15       3                    7                      7
# 14                   1       3                    1                     14
# 15                   1       3                    1                      6
# 16                  13       1                    1                     10
# 17                   8       3                    5                     13
# 18                   3       3                    7                     15
# 19                   0       3                    7                     11
# 20                   8       3                    5                     13
# 21                   9       3                    5                     12
# 22                   7       3                    7                     15
#
#     Text_3  Text_4  Sub_Object_Description  Location_Description       FTE  \
# 0        3       5                       5                     4  0.149912
# 1        3       5                       5                     1  0.149912
# 2        3       5                       5                     0  0.149912
# 3        3       5                       5                     4  1.000000
# 4        3       4                       0                     2  0.149912
# 5        3       5                       5                     4  0.149912
# 6        0       5                       5                     4  1.004141
# 7        3       5                       2                     4  0.149912
# 8        3       5                       5                     4  0.149912
# 9        3       3                       5                     4  0.952253
# 10       1       5                       5                     4  0.149912
# 11       2       5                       5                     4  0.004310
# 12       3       5                       5                     4  0.149912
# 13       3       5                       5                     4  1.000000
# 14       3       5                       5                     4  0.149912
# 15       3       5                       5                     4  0.149912
# 16       1       5                       5                     4  0.149912
# 17       3       1                       3                     2  0.149912
# 18       3       0                       1                     3  0.149912
# 19       3       5                       5                     2  1.000000
# 20       3       1                       3                     2  0.149912
# 21       3       5                       4                     2  0.880000
# 22       3       2                       5                     4  0.000000
#
#     Function_Description  Facility_or_Department  Position_Extra  \
# 0                      2                       3               8
# 1                      4                       3               0
# 2                      3                       3               8
# 3                      7                       3               8
# 4                      6                       2               5
# 5                      4                       3               7
# 6                      4                       3               4
# 7                      5                       3               8
# 8                      4                       3               7
# 9                      7                       3               2
# 10                     4                       3               4
# 11                     4                       3               4
# 12                     2                       3               8
# 13                     7                       3               3
# 14                     4                       3               7
# 15                     4                       3               7
# 16                     4                       3               4
# 17                     2                       0               5
# 18                     1                       1               8
# 19                     0                       3               8
# 20                     2                       0               1
# 21                     2                       0               5
# 22                     7                       3               6
#
#            Total  Program_Description  Fund_Description  Text_1   index
# 0     534.000000                    5                 1       8  414351
# 1   10587.085006                   10                 8       0  156609
# 2     382.720000                   13                 0       4   75964
# 3   64644.641650                   13                 8       8  172213
# 4      78.714180                   12                 7       2  348071
# 5     -63.110000                    2                 8       1  446304
# 6   52414.464330                    3                 8       5   66302
# 7   -1062.560000                   13                 6       7  325427
# 8     -15.020000                    2                 8       1   49981
# 9   26639.987380                    6                 3       8   29225
# 10    698.860000                    3                 8       5  355235
# 11    129.544985                    4                 8       5  281376
# 12    327.160000                    7                 4       8  111770
# 13  47732.070000                    9                 1       8  214157
# 14    -28.250000                    2                 8       1  341782
# 15   -463.010000                    2                 8       1   29389
# 16     19.175120                    3                 8       5  269605
# 17    152.631020                    1                 2       6  381109
# 18   3693.590000                    0                 2       8  370555
# 19  49676.601090                   13                 1       8  295692
# 20   1945.237692                    1                 2       6  440127
# 21  66465.182680                    8                 2       6  444226
# 22    272.220000                   11                 5       3  151100  >

# %% [markdown]
# ## Using MICE.py (Homegrown algorithm)

# %%
mice_imp = MiceImputer(seed_strategy='most_frequent')

# %%
fitted_val = mice_imp.fit(train_imp)

# %%
miced_data = fitted_val.transform(train_imp)

# %%
train_imp[['FTE','Total']].head()
# Out:
#    FTE        Total
# 0  NaN    534.00000
# 1  NaN          NaN
# 2  NaN    382.72000
# 3  1.0  64644.64165
# 4  NaN     78.71418

# %%
miced_data[['FTE','Total']].head()
# Out:
#         FTE         Total
# 0  0.678208    534.000000
# 1 -0.112092 -41097.959158
# 2  2.606419    382.720000
# 3  1.000000  64644.641650
# 4  0.335888     78.714180

# %% [markdown]
# **Resources:**
#
# 1) https://www.statsmodels.org/dev/generated/statsmodels.imputation.mice.MICEData.html <br>
# 2) https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3074241/ <br>
# 3) https://medium.com/ibm-data-science-experience/missing-data-conundrum-exploration-and-imputation-techniques-9f40abe0fd87
